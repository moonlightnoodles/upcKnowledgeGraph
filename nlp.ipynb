# %%
import pandas as pd

# 加载数据（txt 文件，空格分隔）
data = pd.read_csv('./out/outcome.txt', delimiter=" ", header=None, names=["word", "label"])

# 填补空值（如遇到空行或分隔错误）
data = data.ffill()

# 查看数据前几行
print(data.head())
# Out:
#   word label
# 0    平  B-企业
# 1    安  M-企业
# 2    银  M-企业
# 3    行  M-企业
# 4    股  M-企业

# %%
labels = ["O", "B-企业", "M-企业", "E-企业", "B-主营业务", "M-主营业务", "E-主营业务", "B-行业领域", "M-行业领域", "E-行业领域", "B-主要产品", "M-主要产品", "E-主要产品"]
label_map = {label: idx for idx, label in enumerate(labels)}
num_labels = len(labels)

# %%
# !pip install transformers
# Out:
# ...
#   Using cached safetensors-0.4.5-cp310-none-win_amd64.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
# ...

# %% [markdown]
# # 基于 THUCNEWS数据集和 distilbert-base-chinese 的NLP分类模型

# %%
import os
import jieba
import torch
from transformers import DistilBertTokenizer
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 6
#       4 from transformers import DistilBertTokenizer
#       5 from torch.utils.data import Dataset, DataLoader
# ----> 6 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'
